# %%
# mode = df['Senior Management'].mode().values[0]
# df['Senior Management']= df['Senior Management'].replace(np.nan, mode)
  
# df.isnull().sum()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# iMPORTIG LIBRARIES

# %%
import numpy as np
from sklearn import linear_model
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge,Lasso

# %% [markdown]
# Loading dataset

# %%
df=pd.read_csv("/content/drive/MyDrive/company.csv")

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
d=df[["TV","Sales"]]

# %%
# plt.boxplot(x="TV",data=df)
# plt.show()

# %%
plt.scatter(X_train,y_train)
plt.show()

# %%
X_train,X_test,y_train,y_test=train_test_split(df[["TV"]],d[["Sales"]],test_size=0.3,random_state=2)

# %%
X_train,y_train

# %%
model=linear_model.LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
mseloss=mean_squared_error(y_test,y_pred)
r2_loss2=r2_score(y_test,y_pred)
mae_loss=mean_absolute_error(y_test,y_pred)
print("MSE :",mseloss,"\nMAE :",mae_loss,"\nr2_score :",r2_loss2,"\nRMSE :",(mseloss)**(1/2))
# Out:
# MSE : 6.041440872775866
# MAE : 1.9119053871781848
# r2_score : 0.7651379928818157
# RMSE : 2.4579342694172817

# %%
torch.save(model,"/content/drive/MyDrive/Colab Notebooks/modellinear")

# %%
r=Lasso(alpha=20.0)
r.fit(X_train,y_train)
# Out:
# Lasso(alpha=20.0)

# %%
# https://github.com/sridevibonthu/FML/blob/main/multivariate-train-test-split-Boston.ipynb

# %%
y_pred=model.predict(X_test)
mseloss=mean_squared_error(y_test,y_pred)
r2_loss2=r2_score(y_test,y_pred)
mae_loss=mean_absolute_error(y_test,y_pred)
print("MSE :",mseloss,"\nMAE :",mae_loss,"\nr2_score :",r2_loss2,"\nRMSE :",(mseloss)**(1/2))
# Out:
# MSE : 6.041440872775866
# MAE : 1.9119053871781848
# r2_score : 0.7651379928818157
# RMSE : 2.4579342694172817

# %%
import torch
torch.save(model,"/content/drive/MyDrive/Colab Notebooks/model")

# %%
r=Lasso(alpha=20.0)
r.fit(X_train,y_train)
# Out:
# Lasso(alpha=20.0)

# %%
y_pred=model.predict(X_test)
mseloss=mean_squared_error(y_test,y_pred)
r2_loss2=r2_score(y_test,y_pred)
mae_loss=mean_absolute_error(y_test,y_pred)
print("MSE :",mseloss,"\nMAE :",mae_loss,"\nr2_score :",r2_loss2,"\nRMSE :",(mseloss)**(1/2))
# Out:
# MSE : 6.041440872775866
# MAE : 1.9119053871781848
# r2_score : 0.7651379928818157
# RMSE : 2.4579342694172817

# %%
torch.save(model,"/content/drive/MyDrive/Colab Notebooks/modellasso")
