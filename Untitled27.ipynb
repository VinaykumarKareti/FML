# %%
import numpy as np
from sklearn import linear_model
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge,Lasso

# %%
df=pd.read_csv("/content/drive/MyDrive/50_Startups.csv")

# %%
df.isnull().sum()
df.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
df["State"].replace(["New York","California","Florida"],[1,2,3],inplace=True)

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend  State     Profit
# 0   165349.20       136897.80        471784.10      1  192261.83
# 1   162597.70       151377.59        443898.53      2  191792.06
# 2   153441.51       101145.55        407934.54      3  191050.39
# 3   144372.41       118671.85        383199.62      1  182901.99
# 4   142107.34        91391.77        366168.42      3  166187.94
# 5   131876.90        99814.71        362861.36      1  156991.12
# 6   134615.46       147198.87        127716.82      2  156122.51
# 7   130298.13       145530.06        323876.68      3  155752.60
# 8   120542.52       148718.95        311613.29      1  152211.77
# 9   123334.88       108679.17        304981.62      2  149759.96
# 10  101913.08       110594.11        229160.95      3  146121.95
# 11  100671.96        91790.61        249744.55      2  144259.40
# 12   93863.75       127320.38        249839.44      3  141585.52
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(df[["R&D Spend","Administration","Marketing Spend","State"]],df[["Profit"]],test_size=0.2,random_state=1232)

# %%
rid=Ridge(alpha=10.0)
rid.fit(X_train,y_train)
y_pred2=rid.predict(X_train)

# %%
model=linear_model.LinearRegression()
model.fit(X_train,y_train)
y_pred=model.predict(X_test)

# %%
import seaborn as sns
sns.pairplot(df)

# %%
mse=mean_squared_error(y_pred,y_train)
mse2=mean_squared_error(y_pred2,y_train)
mae=mean_absolute_error(y_pred,y_test)
r2=r2_score(y_pred,y_test)
mse,mse2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-14a30a821e79> in <module>
# ----> 1 mse=mean_squared_error(y_pred,y_train)
#       2 mse2=mean_squared_error(y_pred2,y_train)
#       3 mae=mean_absolute_error(y_pred,y_test)
#       4 r2=r2_score(y_pred,y_test)
#       5 mse,mse2
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     440     0.825...
#     441     """
# --> 442     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     443         y_true, y_pred, multioutput
#     444     )
#
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      98         correct keyword.
#      99     """
# --> 100     check_consistent_length(y_true, y_pred)
# ...
